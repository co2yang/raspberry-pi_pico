# %%
print("Hello! Python")
# Out:
# Hello! Python

# %%
a = 10
b = 3
print(a + b)    #13
print(a / b)    #3.3333333333333335 
print(a // b)   #3 整數除法
print(a % b)    #1 餘數
print(a ** b)   #1000 次方
# Out:
# 13
# 3.3333333333333335
# 3
# 1
# 1000

# %%
5 + 10
20 - 15
# Out:
# 5

# %%
n1 = 5 + 10
n2 = 20 - 15
n1
n2
# Out:
# 5

# %%
print(10)
print(20 + 10)
# Out:
# 10
# 30

# %%
a
b
# Out:
# 3
